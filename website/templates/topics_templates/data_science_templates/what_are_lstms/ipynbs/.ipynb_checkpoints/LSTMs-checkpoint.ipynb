# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import mean_squared_error
import numpy as np
np.random.seed(2)
import matplotlib.pyplot as plt
import math
import pandas as pd

# %%
points = np.arange(0, 100, 0.1);
amplitude   = np.sin(points)
plt.figure(figsize=(12,6))
plt.plot(points, amplitude,color='blue')
plt.title('Sine wave')
plt.xlabel('Points')
plt.show()

# %%
# split into train and test sets
train_size = int(len(amplitude) * 0.67)
test_size = len(amplitude) - train_size
train, test = amplitude[0:train_size], amplitude[train_size:]
print(len(train), len(test))
# Out:
# 670 330

# %%
def create_target(data,lookback):
    return data[:-lookback],data[lookback:]
trainX,trainY = create_target(train,1)
testX,testY = create_target(test,1)
print(len(trainX),len(trainY))
# Out:
# 669 669

# %%
# reshape input to be [samples, time steps, features]
trainX = trainX.reshape(-1,1)
testX  = testX.reshape(-1,1)
print(trainX.shape)
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
print(trainX.shape)
# Out:
# (669, 1)
# (669, 1, 1)

# %%
lookback = 1
model = Sequential()
model.add(LSTM(4, input_shape=(1, lookback),activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=10, verbose=2)
# Out:
# Epoch 1/100
# 67/67 - 1s - loss: 0.4593 - 801ms/epoch - 12ms/step
# Epoch 2/100
# 67/67 - 0s - loss: 0.4221 - 49ms/epoch - 731us/step
# Epoch 3/100
# 67/67 - 0s - loss: 0.3661 - 49ms/epoch - 731us/step
# Epoch 4/100
# 67/67 - 0s - loss: 0.2951 - 54ms/epoch - 806us/step
# Epoch 5/100
# 67/67 - 0s - loss: 0.2272 - 48ms/epoch - 716us/step
# Epoch 6/100
# 67/67 - 0s - loss: 0.1750 - 48ms/epoch - 716us/step
# Epoch 7/100
# 67/67 - 0s - loss: 0.1382 - 49ms/epoch - 731us/step
# Epoch 8/100
# 67/67 - 0s - loss: 0.1115 - 49ms/epoch - 731us/step
# Epoch 9/100
# 67/67 - 0s - loss: 0.0916 - 47ms/epoch - 701us/step
# Epoch 10/100
# 67/67 - 0s - loss: 0.0767 - 48ms/epoch - 716us/step
# Epoch 11/100
# 67/67 - 0s - loss: 0.0649 - 49ms/epoch - 731us/step
# Epoch 12/100
# 67/67 - 0s - loss: 0.0560 - 49ms/epoch - 731us/step
# Epoch 13/100
# 67/67 - 0s - loss: 0.0485 - 48ms/epoch - 716us/step
# Epoch 14/100
# 67/67 - 0s - loss: 0.0424 - 48ms/epoch - 718us/step
# Epoch 15/100
# 67/67 - 0s - loss: 0.0373 - 48ms/epoch - 716us/step
# Epoch 16/100
# 67/67 - 0s - loss: 0.0328 - 49ms/epoch - 731us/step
# Epoch 17/100
# 67/67 - 0s - loss: 0.0290 - 49ms/epoch - 731us/step
# Epoch 18/100
# 67/67 - 0s - loss: 0.0257 - 51ms/epoch - 761us/step
# Epoch 19/100
# 67/67 - 0s - loss: 0.0228 - 57ms/epoch - 851us/step
# Epoch 20/100
# 67/67 - 0s - loss: 0.0204 - 55ms/epoch - 821us/step
# Epoch 21/100
# 67/67 - 0s - loss: 0.0183 - 55ms/epoch - 821us/step
# Epoch 22/100
# 67/67 - 0s - loss: 0.0164 - 56ms/epoch - 836us/step
# Epoch 23/100
# 67/67 - 0s - loss: 0.0149 - 53ms/epoch - 791us/step
# Epoch 24/100
# 67/67 - 0s - loss: 0.0135 - 51ms/epoch - 761us/step
# Epoch 25/100
# 67/67 - 0s - loss: 0.0124 - 51ms/epoch - 761us/step
# Epoch 26/100
# 67/67 - 0s - loss: 0.0113 - 50ms/epoch - 746us/step
# Epoch 27/100
# 67/67 - 0s - loss: 0.0105 - 49ms/epoch - 731us/step
# Epoch 28/100
# 67/67 - 0s - loss: 0.0097 - 48ms/epoch - 716us/step
# Epoch 29/100
# 67/67 - 0s - loss: 0.0090 - 48ms/epoch - 716us/step
# Epoch 30/100
# 67/67 - 0s - loss: 0.0085 - 48ms/epoch - 716us/step
# Epoch 31/100
# 67/67 - 0s - loss: 0.0079 - 48ms/epoch - 716us/step
# Epoch 32/100
# 67/67 - 0s - loss: 0.0075 - 54ms/epoch - 806us/step
# Epoch 33/100
# 67/67 - 0s - loss: 0.0072 - 54ms/epoch - 806us/step
# Epoch 34/100
# 67/67 - 0s - loss: 0.0069 - 52ms/epoch - 776us/step
# Epoch 35/100
# 67/67 - 0s - loss: 0.0065 - 54ms/epoch - 806us/step
# Epoch 36/100
# 67/67 - 0s - loss: 0.0063 - 52ms/epoch - 776us/step
# Epoch 37/100
# 67/67 - 0s - loss: 0.0061 - 52ms/epoch - 776us/step
# Epoch 38/100
# 67/67 - 0s - loss: 0.0059 - 51ms/epoch - 761us/step
# Epoch 39/100
# 67/67 - 0s - loss: 0.0058 - 50ms/epoch - 746us/step
# Epoch 40/100
# 67/67 - 0s - loss: 0.0057 - 49ms/epoch - 731us/step
# Epoch 41/100
# 67/67 - 0s - loss: 0.0056 - 53ms/epoch - 798us/step
# Epoch 42/100
# 67/67 - 0s - loss: 0.0055 - 53ms/epoch - 791us/step
# Epoch 43/100
# 67/67 - 0s - loss: 0.0054 - 52ms/epoch - 776us/step
# Epoch 44/100
# 67/67 - 0s - loss: 0.0054 - 49ms/epoch - 731us/step
# Epoch 45/100
# 67/67 - 0s - loss: 0.0053 - 49ms/epoch - 731us/step
# Epoch 46/100
# 67/67 - 0s - loss: 0.0053 - 48ms/epoch - 716us/step
# Epoch 47/100
# 67/67 - 0s - loss: 0.0052 - 50ms/epoch - 746us/step
# Epoch 48/100
# 67/67 - 0s - loss: 0.0052 - 49ms/epoch - 731us/step
# Epoch 49/100
# 67/67 - 0s - loss: 0.0052 - 49ms/epoch - 731us/step
# Epoch 50/100
# 67/67 - 0s - loss: 0.0051 - 49ms/epoch - 731us/step
# Epoch 51/100
# 67/67 - 0s - loss: 0.0052 - 48ms/epoch - 716us/step
# Epoch 52/100
# 67/67 - 0s - loss: 0.0052 - 49ms/epoch - 731us/step
# Epoch 53/100
# 67/67 - 0s - loss: 0.0051 - 48ms/epoch - 716us/step
# Epoch 54/100
# 67/67 - 0s - loss: 0.0051 - 49ms/epoch - 731us/step
# Epoch 55/100
# 67/67 - 0s - loss: 0.0051 - 48ms/epoch - 716us/step
# Epoch 56/100
# 67/67 - 0s - loss: 0.0052 - 48ms/epoch - 716us/step
# Epoch 57/100
# 67/67 - 0s - loss: 0.0051 - 50ms/epoch - 746us/step
# Epoch 58/100
# 67/67 - 0s - loss: 0.0051 - 48ms/epoch - 716us/step
# Epoch 59/100
# 67/67 - 0s - loss: 0.0051 - 50ms/epoch - 746us/step
# Epoch 60/100
# 67/67 - 0s - loss: 0.0051 - 49ms/epoch - 731us/step
# Epoch 61/100
# 67/67 - 0s - loss: 0.0051 - 56ms/epoch - 836us/step
# Epoch 62/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 63/100
# 67/67 - 0s - loss: 0.0051 - 54ms/epoch - 806us/step
# Epoch 64/100
# 67/67 - 0s - loss: 0.0051 - 55ms/epoch - 821us/step
# Epoch 65/100
# 67/67 - 0s - loss: 0.0051 - 54ms/epoch - 806us/step
# Epoch 66/100
# 67/67 - 0s - loss: 0.0051 - 51ms/epoch - 761us/step
# Epoch 67/100
# 67/67 - 0s - loss: 0.0051 - 54ms/epoch - 806us/step
# Epoch 68/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 69/100
# 67/67 - 0s - loss: 0.0051 - 50ms/epoch - 746us/step
# Epoch 70/100
# 67/67 - 0s - loss: 0.0051 - 50ms/epoch - 746us/step
# Epoch 71/100
# 67/67 - 0s - loss: 0.0051 - 51ms/epoch - 761us/step
# Epoch 72/100
# 67/67 - 0s - loss: 0.0051 - 54ms/epoch - 806us/step
# Epoch 73/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 74/100
# 67/67 - 0s - loss: 0.0051 - 54ms/epoch - 806us/step
# Epoch 75/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 76/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 77/100
# 67/67 - 0s - loss: 0.0051 - 56ms/epoch - 836us/step
# Epoch 78/100
# 67/67 - 0s - loss: 0.0051 - 53ms/epoch - 791us/step
# Epoch 79/100
# 67/67 - 0s - loss: 0.0051 - 51ms/epoch - 761us/step
# Epoch 80/100
# 67/67 - 0s - loss: 0.0051 - 53ms/epoch - 791us/step
# Epoch 81/100
# 67/67 - 0s - loss: 0.0051 - 51ms/epoch - 761us/step
# Epoch 82/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 83/100
# 67/67 - 0s - loss: 0.0051 - 53ms/epoch - 791us/step
# Epoch 84/100
# 67/67 - 0s - loss: 0.0051 - 54ms/epoch - 808us/step
# Epoch 85/100
# 67/67 - 0s - loss: 0.0051 - 54ms/epoch - 806us/step
# Epoch 86/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 87/100
# 67/67 - 0s - loss: 0.0051 - 51ms/epoch - 761us/step
# Epoch 88/100
# 67/67 - 0s - loss: 0.0051 - 54ms/epoch - 806us/step
# Epoch 89/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 90/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 91/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 92/100
# 67/67 - 0s - loss: 0.0051 - 51ms/epoch - 761us/step
# Epoch 93/100
# 67/67 - 0s - loss: 0.0051 - 51ms/epoch - 761us/step
# Epoch 94/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 95/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 96/100
# 67/67 - 0s - loss: 0.0051 - 53ms/epoch - 791us/step
# Epoch 97/100
# 67/67 - 0s - loss: 0.0051 - 52ms/epoch - 776us/step
# Epoch 98/100
# 67/67 - 0s - loss: 0.0051 - 53ms/epoch - 791us/step
# Epoch 99/100
# 67/67 - 0s - loss: 0.0051 - 53ms/epoch - 791us/step
# Epoch 100/100
# 67/67 - 0s - loss: 0.0051 - 50ms/epoch - 746us/step

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 4)                 96
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_preds = model.predict(trainX)
test_preds = model.predict(testX)
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, train_preds[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, test_preds[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.07 RMSE
# Test Score: 0.07 RMSE

# %%
preds = np.empty_like(amplitude)
preds[1:train_size] = train_preds[:,0]
preds[train_size+1:] = test_preds[:,0]
df = pd.DataFrame([amplitude,preds,preds]).T
df[1][0] = np.nan
df[1][train_size:] = np.nan
df[2][:train_size+1] =np.nan

# %%
fig,ax = plt.subplots(2,1,figsize=(12,6))
df[0].plot(ax=ax[0],label='actual',color='b')
df[1].plot(ax=ax[1],label='train',color='g',linestyle='--')
df[2].plot(ax=ax[1],label='test',color='r',linestyle='--')
ax[0].set_title('Actual')
ax[1].set_title('Preds')
fig.tight_layout()
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torchinfo

# %%
class torch_LSTM(nn.Module):
    def __init__(self):
        super(torch_LSTM,self).__init__()
        self.dense = 1
        self.input_size = 1
        self.hidden_size = 4
        
        self.lstm = nn.LSTM(input_size=self.input_size,hidden_size=self.hidden_size,batch_first=True)
        self.fc_1 = nn.Linear(in_features=self.hidden_size,out_features=self.dense)
        self.relu = nn.Tanh()
        
    def forward(self,x):
        h_0 = Variable(torch.zeros(1, x.size(0), self.hidden_size))
        c_0 = Variable(torch.zeros(1, x.size(0), self.hidden_size))
        output, (hn, cn) = self.lstm(x, (h_0, c_0))
        hn = hn.view(-1, self.hidden_size)
        out = self.relu(hn)
        out = self.fc_1(out) 
        return out

# %%
def train(trainX,testX,trainY,testY,net,epochs):
    net.train()
    optimiser = torch.optim.Adam(net.parameters())
    criterion = torch.nn.MSELoss()
    for epoch in range(epochs):
        outputs = net.forward(trainX)
        optimiser.zero_grad()
        loss = criterion(outputs,trainY)
        loss.backward()
        test_loss = evaluate(net,testX,testY)
        net.train()
        optimiser.step()
        print('Epoch:',epoch,'/',epochs,': Loss=',loss,'---- Test Loss=',test_loss)
    return net,loss,test_loss

def evaluate(net,testX,testY):
    net.eval()
    with torch.no_grad():
        outputs = net(testX)
    return mean_squared_error(testY,outputs)

# %%
model_torch = torch_LSTM()
trainX_tensor = Variable(torch.Tensor(trainX))
testX_tensor = Variable(torch.Tensor(testX))
trainY_tensor = Variable(torch.Tensor(trainY.reshape(-1,1))) 
testY_tensor = Variable(torch.Tensor(testY.reshape(-1,1)))
net,loss,test_loss = train(trainX_tensor,testX_tensor,trainY_tensor,testY_tensor,model_torch,100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-58650258e60c> in <module>
# ----> 1 model_torch = torch_LSTM()
#       2 trainX_tensor = Variable(torch.Tensor(trainX))
#       3 testX_tensor = Variable(torch.Tensor(testX))
#       4 trainY_tensor = Variable(torch.Tensor(trainY.reshape(-1,1)))
#       5 testY_tensor = Variable(torch.Tensor(testY.reshape(-1,1)))
#
# <ipython-input-29-6ad52b17d079> in __init__(self)
#       8         self.lstm = nn.LSTM(input_size=self.input_size,hidden_size=self.hidden_size,batch_first=True)
#       9         self.fc_1 = nn.Linear(in_features=self.hidden_size,out_features=self.dense)
# ---> 10         self.relu = nn.tanh()
#      11
#      12     def forward(self,x):
#
# AttributeError: module 'torch.nn' has no attribute 'tanh'

# %%
torchinfo.summary(model_torch,(1, 1, 1))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# torch_LSTM                               --                        --
# ├─LSTM: 1-1                              [1, 1, 4]                 112
# ├─ReLU: 1-2                              [1, 4]                    --
# ├─Linear: 1-3                            [1, 1]                    5
# ==========================================================================================
# Total params: 117
# Trainable params: 117
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %%
train_preds = net(trainX_tensor).detach().numpy()
test_preds = net(testX_tensor).detach().numpy()
preds = np.empty_like(amplitude)
preds[1:train_size] = train_preds[:,0]
preds[train_size+1:] = test_preds[:,0]
df = pd.DataFrame([amplitude,preds,preds]).T
df[1][0] = np.nan
df[1][train_size:] = np.nan
df[2][:train_size+1] =np.nan

# %%
fig,ax = plt.subplots(2,1,figsize=(12,6))
df[0].plot(ax=ax[0],label='actual',color='b')
df[1].plot(ax=ax[1],label='train',color='g',linestyle='--')
df[2].plot(ax=ax[1],label='test',color='r',linestyle='--')
ax[0].set_title('Actual')
ax[1].set_title('Preds')
fig.tight_layout()
plt.legend()
plt.show()
